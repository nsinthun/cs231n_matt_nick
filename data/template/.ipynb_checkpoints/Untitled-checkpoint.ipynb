# %%
import os
file_list = [i for i in os.listdir() if '.png' in i]
for i in file_list:
    new_name = ['model'] + i.split('-')[1:]

    #os.rename(i,new_name)
    print(i)
    print(new_name)
# Out:
# model11-595-w-2.png
# ['model', '595', 'w', '2.png']
# model9-587-m-1.png
# ['model', '587', 'm', '1.png']
# model11-632-w-1.png
# ['model', '632', 'w', '1.png']
# model11-569-w-2.png
# ['model', '569', 'w', '2.png']
# model3-703-w-3.png
# ['model', '703', 'w', '3.png']
# model3-703-w-2.png
# ['model', '703', 'w', '2.png']
# model11-639-w-2.png
# ['model', '639', 'w', '2.png']
# model8-682-w-2.png
# ['model', '682', 'w', '2.png']
# model9-585-m-2.png
# ['model', '585', 'm', '2.png']
# model9-736-m-2.png
# ['model', '736', 'm', '2.png']
# model9-606-m-2.png
# ['model', '606', 'm', '2.png']
# model11-602-w-1.png
# ['model', '602', 'w', '1.png']
# model11-717-w-1.png
# ['model', '717', 'w', '1.png']
# model8-750-w-2.png
# ['model', '750', 'w', '2.png']
# model11-675-w-1.png
# ['model', '675', 'w', '1.png']
# model9-741-m-1.png
# ['model', '741', 'm', '1.png']
# model11-668-w-2.png
# ['model', '668', 'w', '2.png']
# model8-655-w-1.png
# ['model', '655', 'w', '1.png']
# ...
